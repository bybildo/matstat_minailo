# %% [markdown]
# ---
# # <center> Практична робота №5 </center>
# ## __Тема. Алгоритми пошуку та їх складність__
# ## __Мета:__ опанувати основні алгоритми сортування та навчитись методам аналізу їх асимптотичної складності.
# ### _Викoнав Міняйло Марк 17.05.2024_
# ----

# %% [markdown]
# #### 19) Задано ациклічний граф:{1,2,3,4,5,6,7,8,9}{(1,2),(1,3),(2,4),(3,5),(4,5),(4,6),(6,7),(6,9),(7,8),(7,9),(8,9)}.Побудувати граф і розв’язати задачу топологічного сортування за допомогою алгоритму Кана.
# ![](image/1.jpg)
#
# S = [1]
# | L = []
#
# S = [2, 3]
# | L = [1]
#
# S = [2, 5]
# | L = [1, 3]
#
# S = [2]
# | L = [1, 3, 5]
#
# S = [4]
# | L = [1, 3, 5 ,2]
#
# S = [6]
# | L = [1, 3, 5 ,2, 4]
#
# S = [7]
# | L = [1, 3, 5 ,2, 4, 6]
#
# S = [8]
# | L = [1, 3, 5 ,2, 4, 6, 7]
#
# S = [9]
# | L = [1, 3, 5 ,2, 4, 6, 7, 8]
#
# S = []
# | L = [1, 3, 5 ,2, 4, 6, 7, 8, 9]
#
# ---

# %% [markdown]
# #  <center>  Контрольні запитання </center>
# 1. _Які переваги і недоліки алгоритму Кана порівняно з алгоритмом DFS для топологічного сортування графа?_
#
# Алгоритм Кана має лінійну асимптотичну складність, гарантуєє результат, але не працює з ациклічними графами і не може виявити цикл.
#
# 2. _Яка складність часу і пам’яті для кожного з алгоритмів у найгіршому і найкращому випадках?_
#
# Асимптотична складність алгоритмів може варіюватися залежно від характеристик графа та конкретної реалізації алгоритму
# у найгіршому випадку, це 𝑂(|𝑉| + | 𝐸|)
#
# 3. _Чи можна застосовувати алгоритм Кана до графів з вагами на ребрах? Як це порівняти з DFS?_
#
# Якщо граф має ваги на ребрах, алгоритм Кана можна застосовувати, але ваги не впливатимуть на порядок вершин.
#
# 4. _Як впливає структура графа на швидкість роботи кожного з цих
# алгоритмів?_
#
# У загальному випадку, алгоритм Кана є ефективнішим для густо зв'язаних графів, тоді як DFS може бути кращим варіантом для розріджених графів з меншою кількістю вершин
#
# 5. _Чи є обмеження використання кожного алгоритму для певних типів
# графів або завдань?_
#
# Кан не працює з циклічними графами, але завжди знаходить топологічний порядок, DFS працює з циклічними графами, але не гарантує топологічний порядок.
#
# 6. _Які варіанти оптимізації можна застосувати для кожного алгоритму з
# метою поліпшення його продуктивності?_
#
# Замість зберігання всього шляху в стеку, можна зберігати лише індекси вершин або мітки відвіданих вершин.
#
# ---
